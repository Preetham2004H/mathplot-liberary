# %%
#shuffing arr
from numpy import random
import numpy as np
arr=np.array([10,20,30,40])
random.shuffle(arr)
print(arr)
# Out:
# [40 20 30 10]

# %%
#premution of the array
from numpy import random
import numpy as np
arr=np.array ([11,15,16,17])
print(random.permutation(arr))
# Out:
# [16 17 11 15]

# %%
#sea born module
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot([0,1,2,3,4,5,6])
plt.show()
# Out:
# C:\Users\Library c3\Documents\New folder\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as pp
import seaborn as sea
sea.distplot([10,20,3010,4,20,203,20,50,306,0,506,656,20,560],hist=False)
pp.show()
# Out:
# C:\Users\Library c3\Documents\New folder\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
from numpy import random
x=random.normal(loc=1,scale=2,size=(2,3))
print(x)
# Out:
# [[-0.69577439  1.00850793 -1.22959308]
#  [ 0.98270784  4.58010601  1.15419634]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import random
import seaborn as se
se.distplot(random.normal (size=1000),hist=True)
plt.show
# Out:
# C:\Users\Library c3\Documents\New folder\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from numpy import random
arr=random.binomial(n=10,p=0.5,size=10)
print(arr)
# Out:
# [8 2 5 7 5 5 6 5 6 5]

# %%
from numpy import random 
import matplotlib.pyplot as pp
import seaborn as se
se.distplot(random.binomial(n=10,p=0.5,size=1000),hist=True,kde=False)
pp.show()
# Out:
# C:\Users\Library c3\Documents\New folder\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=True, label='binomial')

plt.show()
# Out:
# C:\Users\Library c3\Documents\New folder\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Library c3\Documents\New folder\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from numpy import random
x=random.poisson(lam=2,size=10)
print(x)
# Out:
# [1 1 0 0 1 1 0 0 2 5]

# %%
import numpy as np 
import matplotlib.pyplot as ppt
x=np.array([10,20,30,40])
y=np.array([100,200,300,400])
ppt.plot(x,y)
ppt.grid()
ppt.show()

# %%
import numpy as np
import matplotlib.pyplot as ppt
x=np.array([10,20,30,40])
y=np.array([12,24,36,48])
ppt.plot(y,"h",x)
ppt.show()
